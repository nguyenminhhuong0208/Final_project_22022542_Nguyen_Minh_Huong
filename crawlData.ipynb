# %%
from facebook_scraper import get_posts
import pandas as pd

# %%
FANPAGE_LINK ="tamlyhoctoipham"
FOLDER_PATH = "New folder"
COOKIE_PATH = "cookies1.txt"

PAGES_NUMBER = 30 # số trang cần cào

# %%
from facebook_scraper import get_posts
import pandas as pd

# %%
post_list = []
for post in get_posts(FANPAGE_LINK, 
                    options={"comments": True, "reactions": True, "allow_extra_requests": True}, 
                    extra_info=True, pages=10, cookies=COOKIE_PATH):
    post_list.append(post)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\facebook_scraper\facebook_scraper.py:855: UserWarning: Facebook language detected as vi_VN - for best results, set to en_US
#   warnings.warn(

# %%
len(post_list)
# Out:
# 10

# %%
post_list[0]
# Out:
# {'post_id': '328578473140550',
# ...

# %%
post_list[0]["comments_full"]
# Out:
# [{'comment_id': '307593878861053',
#   'comment_url': 'https://facebook.com/307593878861053',
#   'commenter_id': '100003620549077',
#   'commenter_url': 'https://facebook.com/rama.anungun?eav=AfZbGQKu-WZoF_SWc-c012t3uyiWlszGgQ1JGukagO3B91HdOlDIXm3Grnyvoaz014k&fref=nf&rc=p&refid=52&__tn__=R&paipv=0',
#   'commenter_name': 'Bcs Kẻ Cầm Cự',
#   'commenter_meta': None,
#   'comment_text': 'Càng nhiều dối trá và che đậy thì càng phải chịu đựng, nó đến từ cả cha mẹ lẫn bản thân con cái.',
#   'comment_time': datetime.datetime(2023, 11, 14, 23, 26),
#   'comment_image': None,
#   'comment_reactors': [],
#   'comment_reactions': None,
#   'comment_reaction_count': None,
#   'replies': []},
#  {'comment_id': '2996770813790853',
#   'comment_url': 'https://facebook.com/2996770813790853',
#   'commenter_id': '100027823337849',
# ...

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
post_df_full.to_excel(FOLDER_PATH + FANPAGE_LINK + ".xlsx", index=False)
print(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Admin\projects\New folder\Untitled-1.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/projects/New%20folder/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # Initialize dataframe to scrape Facebook post
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/projects/New%20folder/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/projects/New%20folder/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # To df
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/projects/New%20folder/Untitled-1.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> path=FOLDER_PATH + FANPAGE_LINK + ".xlsx"
#
# NameError: name 'post_list' is not defined

# %%
post_df_full
# Out:
#             post_id                                               text  \
# 0   328578473140550  🌸 CHỊU ĐỰNG TRONG IM LẶNG – The school of life...
# 1   328554289809635                                 Nguồn: Bright Side
# 2   328530266478704  💟 “Tâm lý học nói rằng: Bạn không sợ yêu, bạn ...
# 3   328513479813716  🌸 ĐỪNG TIN BỘ NÃO CỦA BẠN: TẠI SAO CHÚNG TA PH...
# 4   328486706483060  “Là một nhà tâm lý trị liệu, cho phép tôi nói ...
# ..              ...                                                ...
# 95  316585667673164  🌸 ĐỜI THƯỜNG KÌ DIỆU: VÌ SAO ĐƯỢC SỐNG MỘT CUỘ...
# 96  316206724377725  "Đây là một điều ngờ nghệch của người đời: khi...
# 97  316125614385836  🌿 HIỂU VỀ SỰ THẤU CẢM - The School Of Life\n\n...
# 98  316081317723599  ĐỂ TỰ TIN, CÓ THỰC SỰ KHÓ ĐẾN VẬY KHÔNG\n\nChủ...
# 99  316056897726041  🍀 SỰ BUÔNG XẢ TRONG PHẬT GIÁO CÓ GIÚP MỐI QUAN...
#
#                                             post_text shared_text  \
# ...

# %%
import pandas as pd
df = pd.read_excel('projectfinaltamlyhoctoipham1.xlsx')
df.columns[24:51].to_list()
# Out:
# ['shares',
#  'post_url',
#  'link',
#  'links',
#  'user_id',
#  'username',
#  'user_url',
#  'is_live',
#  'factcheck',
#  'shared_post_id',
#  'shared_time',
#  'shared_user_id',
#  'shared_username',
#  'shared_post_url',
#  'available',
#  'comments_full',
#  'reactors',
#  'w3_fb_url',
#  'reactions',
#  'reaction_count',
#  'with',
#  'page_id',
#  'sharers',
#  'image_id',
#  'image_ids',
#  'was_live',
#  'fetched_time']
